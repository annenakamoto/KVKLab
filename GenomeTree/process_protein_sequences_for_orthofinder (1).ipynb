# %%
from Bio import SeqIO
import sys
import os
import shutil
import csv

# %%
seq_dir = sys.argv[1]
out_dir = sys.argv[2]

# %%
seq_dir = 'proteomes_combined_for_orthofinder'
out_dir = 'proteomes_combined_for_orthofinder_corrected'
lineage_info_file = 'gladieux_et_al_assembly_stats.txt'

# %%
lineage_info = {}
with open(lineage_info_file, newline = '') as file:
    file_reader = csv.reader(file, delimiter = '\t')
    for row in file_reader:
        if row[0] == 'WD-3-1_1':
            lineage_info['WD-3-1'] = row[2]+'_'+row[3]
        else:
            lineage_info[row[0]] = row[2]+'_'+row[3]

# %%
seq_list = os.listdir(seq_dir)

# %%
if os.path.isdir(out_dir):
    shutil.rmtree(out_dir)
os.mkdir(out_dir)

# %%
for seq in seq_list:
    print(seq)
    if '_fungap_out_prot.faa' in seq:
        accession = seq.split('_')[0] + seq.split('_')[1]
    elif seq == 'GCA_000002495.2_MG8_protein.faa':
        accession = '70-15'
    elif seq == 'GCA_004355905.1_PgNI_protein.faa':
        accession = 'NI907'
    elif '_protein.fasta' in seq:
        isolate = seq.split('_')[0]
        lineage = lineage_info[isolate]
        accession = seq.split('_')[0] + '_' + lineage
    else:
        print('couldnt process accession')
    print(accession)
    out_file = out_dir + '/' + accession + '_proteome_filtered.fasta'
    seq_path = seq_dir + '/' + seq
    record_list = list(SeqIO.parse(seq_path, 'fasta'))
    with open(out_file, 'w') as corrected:
        for i in range(len(record_list)):
            record = record_list[i]
            record.id = 'gene_' + str(i) + '_' + accession ## rename records to have genome name in them
            record.description = ''
            if '*' in record.seq:
                if record.seq[-1] == '*': ## remove stop codon from end of sequences
                    record.seq = record.seq[:-1]
                    SeqIO.write(record, corrected, 'fasta')
            else:
                SeqIO.write(record, corrected, 'fasta')
# Out:
# 13FM-16-1_protein.fasta
# 13FM-16-1_1_Baoshan
# 13FM-24-1_protein.fasta
# 13FM-24-1_1_International
# 13FM-3-2_protein.fasta
# 13FM-3-2_2_NA
# 13FM-5-1_protein.fasta
# 13FM-5-1_1_International
# AG0004_protein.fasta
# AG0004_2_NA
# AV1-1-1_protein.fasta
# AV1-1-1_3_NA
# BJ-90-611_protein.fasta
# BJ-90-611_2_NA
# BJ08-8_protein.fasta
# BJ08-8_2_NA
# BN0123_protein.fasta
# BN0123_4_NA
# BN0202_protein.fasta
# BN0202_2_NA
# BN0252_protein.fasta
# BN0252_3_NA
# CD0065_protein.fasta
# CD0065_1_International
# CD0142_protein.fasta
# CD0142_1_International
# CH0043_protein.fasta
# CH0043_1_International
# CH0072_protein.fasta
# CH0072_1_Laos
# CH0452_protein.fasta
# CH0452_1_International
# CH0461_protein.fasta
# CH0461_1_Laos
# CH1103_protein.fasta
# CH1103_1_International
# CH1164_protein.fasta
# CH1164_1_Laos
# CM0028_protein.fasta
# CM0028_3_NA
# DB11-621_protein.fasta
# DB11-621_2_NA
# FJ0204804_protein.fasta
# FJ0204804_3_NA
# FJ11SH-527-1_protein.fasta
# FJ11SH-527-1_3_NA
# FJ12JN-084-3_protein.fasta
# FJ12JN-084-3_3_NA
# FJ13SH05-2_protein.fasta
# FJ13SH05-2_3_NA
# FJ2000-62A_protein.fasta
# FJ2000-62A_3_NA
# FJ2000-69A_protein.fasta
# FJ2000-69A_3_NA
# FJ2001-112B_protein.fasta
# FJ2001-112B_3_NA
# FJ2003-001A1_protein.fasta
# FJ2003-001A1_3_NA
# FJ2005113B_protein.fasta
# FJ2005113B_3_NA
# FJ2006-60A3_protein.fasta
# FJ2006-60A3_3_NA
# FJ72ZC7-77_protein.fasta
# FJ72ZC7-77_3_NA
# FJ78-JJ_protein.fasta
# FJ78-JJ_2_NA
# FJ81-JY_protein.fasta
# FJ81-JY_2_NA
# FJ81-SW_protein.fasta
# FJ81-SW_2_NA
# FJ81-ZP_protein.fasta
# FJ81-ZP_2_NA
# FJ81221ZB11-14_protein.fasta
# FJ81221ZB11-14_2_NA
# FJ86-CT_protein.fasta
# FJ86-CT_2_NA
# FJ86061ZE3-39_protein.fasta
# FJ86061ZE3-39_2_NA
# FJ95054B_protein.fasta
# FJ95054B_2_NA
# FJ95085AZB13-116_protein.fasta
# FJ95085AZB13-116_3_NA
# FJ98099_protein.fasta
# FJ98099_3_NA
# FJ99138_protein.fasta
# FJ99138_3_NA
# FJSH0703_protein.fasta
# FJSH0703_3_NA
# GCA_000002495.2_MG8_protein.faa
# 70-15
# GCA_000475075.1_HN19311_genome_assembly_fungap_out_prot.faa
# GCA000475075.1
# GCA_000498135.1_FJ81278_genome_assembly_fungap_out_prot.faa
# GCA000498135.1
# GCA_000734075.1_Mo2303.1_fungap_out_prot.faa
# GCA000734075.1
# GCA_000734095.1_Mo1106.2_fungap_out_prot.faa
# GCA000734095.1
# GCA_000734215.1_Mo4603.4_fungap_out_prot.faa
# GCA000734215.1
# GCA_000734245.1_MoJS25_fungap_out_prot.faa
# GCA000734245.1
# GCA_000734315.1_MoZJ15_fungap_out_prot.faa
# GCA000734315.1
# GCA_000734335.1_MoAH06_fungap_out_prot.faa
# GCA000734335.1
# GCA_000832285.1_M_oryzae_b157_v1_fungap_out_prot.faa
# GCA000832285.1
# GCA_000969745.1_M_oryzae_MG01_v1_fungap_out_prot.faa
# GCA000969745.1
# GCA_001936075.1_ASM193607v1_fungap_out_prot.faa
# GCA001936075.1
# GCA_001936435.1_ASM193643v1_fungap_out_prot.faa
# GCA001936435.1
# GCA_002105295.1_ASM210529v1_fungap_out_prot.faa
# GCA002105295.1
# GCA_002218345.1_H08-1a_0.9_fungap_out_prot.faa
# GCA002218345.1
# GCA_002218355.1_H08-1c_0.9_fungap_out_prot.faa
# GCA002218355.1
# GCA_002368475.1_ASM236847v1_fungap_out_prot.faa
# GCA002368475.1
# GCA_002368485.1_ASM236848v1_fungap_out_prot.faa
# GCA002368485.1
# GCA_002368515.1_ASM236851v1_fungap_out_prot.faa
# GCA002368515.1
# GCA_002368525.1_ASM236852v1_fungap_out_prot.faa
# GCA002368525.1
# GCA_002924965.1_ASM292496v1_fungap_out_prot.faa
# GCA002924965.1
# GCA_002924985.1_ASM292498v1_fungap_out_prot.faa
# GCA002924985.1
# GCA_002925025.1_ASM292502v1_fungap_out_prot.faa
# GCA002925025.1
# GCA_002925045.1_ASM292504v1_fungap_out_prot.faa
# GCA002925045.1
# GCA_002925065.1_ASM292506v1_fungap_out_prot.faa
# GCA002925065.1
# GCA_002925085.1_ASM292508v1_fungap_out_prot.faa
# GCA002925085.1
# GCA_002925095.1_ASM292509v1_fungap_out_prot.faa
# GCA002925095.1
# GCA_002925215.1_ASM292521v1_fungap_out_prot.faa
# GCA002925215.1
# GCA_003013125.1_ASM301312v1_fungap_out_prot.faa
# GCA003013125.1
# GCA_003015465.1_ASM301546v1_fungap_out_prot.faa
# GCA003015465.1
# GCA_003015595.1_ASM301559v1_fungap_out_prot.faa
# GCA003015595.1
# GCA_003015805.1_ASM301580v1_fungap_out_prot.faa
# GCA003015805.1
# GCA_003016085.1_ASM301608v1_fungap_out_prot.faa
# GCA003016085.1
# GCA_003016175.1_ASM301617v1_fungap_out_prot.faa
# GCA003016175.1
# GCA_003016785.1_ASM301678v1_fungap_out_prot.faa
# GCA003016785.1
# GCA_003990535.1_Moryzae-RP-2421.1.0_fungap_out_prot.faa
# GCA003990535.1
# GCA_003991345.1_ASM399134v1_fungap_out_prot.faa
# GCA003991345.1
# GCA_004355905.1_PgNI_protein.faa
# NI907
# GCA_011799905.1_ASM1179990v1_fungap_out_prot.faa
# GCA011799905.1
# GCA_011799915.1_ASM1179991v1_fungap_out_prot.faa
# GCA011799915.1
# GCA_011799925.1_ASM1179992v1_fungap_out_prot.faa
# GCA011799925.1
# GCA_011799965.1_ASM1179996v1_fungap_out_prot.faa
# GCA011799965.1
# GCA_012922935.1_ASM1292293v1_fungap_out_prot.faa
# GCA012922935.1
# GCA_900474655.3_FR13_genome_polished_no_mito_fungap_out_prot.faa
# GCA900474655.3
# GD06-53_protein.fasta
# GD06-53_3_NA
# GD08-2025_protein.fasta
# GD08-2025_3_NA
# GY0040_protein.fasta
# GY0040_3_NA
# HB-14_protein.fasta
# HB-14_4_NA
# HB-LTH18_protein.fasta
# HB-LTH18_1_International
# HN-0812-3_protein.fasta
# HN-0812-3_2_NA
# HN-158_protein.fasta
# HN-158_3_NA
# HN10-1604_protein.fasta
# HN10-1604_3_NA
# IA1_protein.fasta
# IA1_2_NA
# IB33_protein.fasta
# IB33_4_NA
# IB49_protein.fasta
# IB49_1_International
# IC17_protein.fasta
# IC17_1_International
# IE1K_protein.fasta
# IE1K_1_International
# IN0017_protein.fasta
# IN0017_4_NA
# IN0054_protein.fasta
# IN0054_1_International
# IN0059_protein.fasta
# IN0059_4_NA
# IN0114_protein.fasta
# IN0114_1_International
# IN0115_protein.fasta
# IN0115_1_International
# IN0116_protein.fasta
# IN0116_1_International
# IT0010_protein.fasta
# IT0010_2_NA
# JS08-611_protein.fasta
# JS08-611_2_NA
# JS09-138_protein.fasta
# JS09-138_2_NA
# JX-09Z116-1_protein.fasta
# JX-09Z116-1_2_NA
# JX10-102_protein.fasta
# JX10-102_2_NA
# JX11-141_protein.fasta
# JX11-141_2_NA
# KA1-3-1_protein.fasta
# KA1-3-1_3_NA
# KA2-1-1_protein.fasta
